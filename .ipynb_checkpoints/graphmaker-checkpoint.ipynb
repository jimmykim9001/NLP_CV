# %%
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, plot_roc_curve, recall_score, classification_report, f1_score)
import matplotlib.pyplot as plt
import pandas as pd
import scikitplot as skplt
import seaborn as sns

# %%
df = pd.read_csv("logs/res.csv", index_col=0)
metrics= pd.read_csv("logs/metrics.csv")

# %%
def make_graphs(data, metrics):
    df = pd.read_csv("logs/res.csv", index_col=0)
    metrics= pd.read_csv("logs/metrics.csv")
#script: train, validation, metrics

# %%
metrics
# Out:
#       train_loss_step  epoch  step  train_loss_epoch  train_accuracy
# 0        6.859371e-01      0     0               NaN             NaN
# 1        6.853768e-01      0     1               NaN             NaN
# 2        7.362214e-01      0     2               NaN             NaN
# 3        6.955161e-01      0     3               NaN             NaN
# 4        6.793473e-01      0     4               NaN             NaN
# ...               ...    ...   ...               ...             ...
# 2005     8.344647e-07      9  1996               NaN             NaN
# 2006     2.751430e-02      9  1997               NaN             NaN
# 2007     8.940693e-07      9  1998               NaN             NaN
# 2008     5.364417e-07      9  1999               NaN             NaN
# 2009              NaN      9  1999          0.070126           0.965
#
# [2010 rows x 5 columns]

# %%
df
# Out:
#          prob_zero      prob_one  pred  correct
# 0     4.925187e-01  5.074812e-01     1        1
# 1     4.920153e-01  5.079847e-01     1        1
# 2     4.582812e-01  5.417188e-01     1        0
# 3     4.976349e-01  5.023651e-01     1        0
# 4     5.138935e-01  4.861065e-01     0        0
# ...            ...           ...   ...      ...
# 1995  9.958793e-01  4.120750e-03     0        0
# 1996  1.000000e+00  7.024585e-13     0        0
# 1997  9.992232e-01  7.767166e-04     0        0
# 1998  7.865212e-13  1.000000e+00     1        1
# 1999  1.000000e+00  2.976616e-13     0        0
#
# [2000 rows x 4 columns]

# %%
def calc_confusion_matrix_for_threshold(ytrue_N, yproba1_N, thresh):
    cm = confusion_matrix(ytrue_N, yproba1_N >= thresh)
    cm_df = pd.DataFrame(data=cm, columns=[0, 1], index=[0, 1])
    cm_df.columns.name = 'Predicted'
    cm_df.index.name = 'True'
    return cm_df

# %%
calc_confusion_matrix_for_threshold(df["correct"],  df["pred"], 0.5)
# Out:
# Predicted    0    1
# True
# 0          792  208
# 1          151  849

# %%
df[["prob_zero", "prob_one"]].values
# Out:
# array([[4.92518723e-01, 5.07481217e-01],
#        [4.92015272e-01, 5.07984698e-01],
#        [4.58281219e-01, 5.41718841e-01],
#        ...,
#        [9.99223232e-01, 7.76716624e-04],
#        [7.86521239e-13, 1.00000000e+00],
#        [1.00000000e+00, 2.97661581e-13]])

# %%
train_acc =metrics["train_accuracy"].dropna()

# %%
trainAccs = train_acc.values.tolist()

# %%
trainAccs
# Out:
# [0.5649999976158142,
#  0.6850000023841858,
#  0.7400000095367432,
#  0.7950000166893005,
#  0.8199999928474426,
#  0.8949999809265137,
#  0.9300000071525574,
#  0.9300000071525574,
#  0.8799999952316284,
#  0.9649999737739564]

# %%
x = range(len(trainAccs))
y = trainAccs
  
# plotting
plt.title("Training Accuracy") 
plt.xlabel("Epochs") 
plt.ylabel("Accuracy") 
plt.plot(x, y, color ="red", label="training")
plt.legend()
plt.show()

# %%
y_probas = df[["prob_zero", "prob_one"]].values

# %%
skplt.metrics.plot_roc(df["correct"], y_probas)
plt.show()

# %%
skplt.metrics.plot_precision_recall(df["correct"], y_probas)
plt.show()
